# %%
# 📍 Step 1: Clone YOLOv5 and install dependencies
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# c:\Users\ACER\Desktop\new safevision\dataset\yolov5
# Cloning into 'yolov5'...
# C:\Users\ACER\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# ^C
# ...
#    ---------------------------------------- 0.0/216.1 MB ? eta -:--:--
#    ---------------------------------------- 1.0/216.1 MB 4.6 MB/s eta 0:00:48
#    ---------------------------------------- 2.4/216.1 MB 5.4 MB/s eta 0:00:40
#     --------------------------------------- 4.2/216.1 MB 6.5 MB/s eta 0:00:33
#    - -------------------------------------- 6.0/216.1 MB 7.1 MB/s eta 0:00:30
#    - -------------------------------------- 7.1/216.1 MB 6.9 MB/s eta 0:00:31
#    - -------------------------------------- 8.4/216.1 MB 6.6 MB/s eta 0:00:32
#    - -------------------------------------- 10.0/216.1 MB 6.7 MB/s eta 0:00:31
# ...

# %%
# 📍 Step 2: Check GPU availability
import torch
torch.cuda.is_available()
# Out:
# False

# %%
# 📍 Step 3: Preview your dataset.yaml file
# Make sure this file exists at: ../women_safety_dataset/data.yaml

# !cat ../women_safety_dataset/data.yaml
# Out:
# cat: ../women_safety_dataset/data.yaml: No such file or directory

# %%
train: ../women_safety_dataset/train/images
val: ../women_safety_dataset/valid/images
test: ../women_safety_dataset/test/images

nc: 3
names: ['Alone woman', 'Men attacking woman', 'Woman followed by men']
# Out:
#   Cell In[10], line 1
#     train: ../women_safety_dataset/train/images
#            ^
# SyntaxError: invalid syntax

# %%
# 📍 Step 4: Start Training the Model
# !python train.py --img 640 --batch 16 --epochs 50 --data ../women_safety_dataset/data.yaml --weights yolov5s.pt --name woman_safety_model

# %%
# 📍 Step 5: Check training results
from IPython.display import Image, display
display(Image(filename='runs/train/woman_safety_model/results.png'))

# %%
# 📍 Step 6: Run Inference on Test Images
# !python detect.py --weights runs/train/woman_safety_model/weights/best.pt --img 640 --source ../women_safety_dataset/test/images --conf 0.4

# %%
yolov5/runs/detect/exp/

# %%
# 📍 Step 7: Display sample inference result
import os
from IPython.display import Image, display

# Show one of the output images
result_path = 'runs/detect/exp'
for image_name in os.listdir(result_path):
    if image_name.endswith(".jpg"):
        display(Image(filename=os.path.join(result_path, image_name)))
        break
